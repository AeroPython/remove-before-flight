# %% [markdown]
# ![PyData_logo](./static/pydata-logo-madrid-2016.png)

# %% [markdown]
# # Remove Before Flight
# ## Analyzing Flight Safety Data with Python

# %% [markdown]
# ### Getting missing values of latitude and longitude with Google geocoding API

# %% [markdown]
# ###### https://developers.google.com/maps/documentation/geocoding/intro?hl=es#geocoding

# %%
import pandas as pd
import numpy as np

# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
# Some configuration options:
pd.set_option('max_columns', 70)
pd.set_option('max_rows', 50)

# %%
# Read the missing locations
need_location = pd.read_csv('./data/need_location.csv', index_col='Unnamed: 0')
need_location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4307 entries, 46 to 76878
# Data columns (total 5 columns):
# ev_city       4285 non-null object
# ev_country    4170 non-null object
# ev_state      2936 non-null object
# latitude      0 non-null float64
# longitude     1 non-null object
# dtypes: float64(1), object(4)
# memory usage: 201.9+ KB

# %%
need_location.tail()
# Out:
#                ev_city ev_country ev_state  latitude longitude
# 76812          Banbury         UK      NaN       NaN       NaN
# 76836  VERMILLION 255B        NaN       GM       NaN       NaN
# 76846           Kigali         RW      NaN       NaN       NaN
# 76850  JUNEAU                 USA       AK       NaN       NaN
# 76878          Cozumel         MX      NaN       NaN       NaN

# %%
from utils.geoloc import GoogleMapsClient

# %%
# read key from file:
# Your API key here https://developers.google.com/maps/documentation/geocoding/get-api-key
with open('./key.txt') as f:
    key = f.readline().rstrip('\n')

# %%
Session = GoogleMapsClient(key=key)

index = need_location.index
cities = need_location['ev_city'].values
states = need_location['ev_state'].values
countries = need_location['ev_country'].values

# %% [markdown]
# As the number of request is limited to 2500 requests per day, the dataframe needs to be splitted:

# %%
# Part 1: 0:1999
for ii in range(2000):
    location = Session.get_lat_lon_from_city_country(cities[ii], countries[ii], states[ii])
    if location != []:
        lat = location[0]
        lon = location[1]
        need_location.set_value(index[ii], 'latitude', lat)
        need_location.set_value(index[ii], 'longitude', lon)
        
need_location.iloc[0:2000].to_csv('./data/have_location_part1.csv')
# Out:
# wrong request: TANZANIA       , SU
# wrong request: Makarakskiy, RS
# wrong request: Egelsbach, GE
# wrong request: W CAMERON BLK  , GM
# wrong request: Sazava, EZ
# wrong request: Reichelheim, GE
# wrong request: GULF OF MEXICO , GM
# wrong request: KAFOUTINE, SG
# wrong request: SOUTH PELTO    , GM
# wrong request: Sulaimaniya, IZ
# wrong request: VOLCANOES NTL P, HI, USA
# wrong request: JEREMIE        , HA
# wrong request: BELL MOUNTAIN  , AK, USA
# wrong request: Alcora, SP
# wrong request: EUGENE ISLAND  , GM
# wrong request: AGO-6, AY
# wrong request: HIGH ISLAND BLK, GM
# wrong request: WALKER'S CAY   , BF
# wrong request: Alcorsia, Teruel, Spain, SP
# wrong request: FREEPORT, BF
# wrong request: MISSING ACFT, AO
# wrong request: WEST DELTA 105 , GM
# wrong request: Apoquindo, CI
# wrong request: E CAMERON BLK 2, GM
# wrong request: Steinfeld, GE
# wrong request: MT MCKINLEY VIL, AK, USA
# wrong request: Santa Juana, CI
# wrong request: Moixent, SP
# wrong request: MIAZAL         , EC
# wrong request: Subic Bay, RP
# wrong request: Meranges, SP
# wrong request: Rio Sidra, PM
# wrong request: Guipuzcoa, SP
# wrong request: Eberebruum, GE
# wrong request: 42NM ESE OF YAK, AK, USA
# wrong request: TANZANIA       , SU
# wrong request: GT. HARBOUR CAY, BF
# wrong request: High Island 138, GM, USA
# wrong request: LITTLE DELTA RV, AK, USA
# wrong request: Quepos, CS
# wrong request: Lawa Antino, NS
# wrong request: Istra, RS
# wrong request: Baindoang, PNG, PP
# wrong request: 6NM SSE WRANGEL, AK, USA
# wrong request: KAKAP, IM
# wrong request: Bohusovice nad Ohri, FN, USA
# wrong request: SHIPSHOAL 295  , GM
# wrong request: Cayo Province, BH
# wrong request: TREASURE CAY, BF
# wrong request: QUEPOS, CS
# wrong request: Guipuzcoa, SP
# wrong request: EUGENE ISLAND  , GM
# wrong request: Tartu, EN
# wrong request: SHIP SHOAL 90  , GM
# wrong request: MISSING        , CB
# wrong request: Borneo Island, FN, MY
# wrong request: Bjornon, FN, SW
# wrong request: Oey, Gemeinde Saanen, SZ
# wrong request: PUNTARENAS     , CS
# wrong request: Ivashka Township, RS
# wrong request: SUBIC BAY      , RP
# wrong request: LA PUNTILLA    , CI
# wrong request: SLIGO AIRPORT  , EI
# wrong request: Izhma, RS
# wrong request: Atlantic Ocean, AO, USA
# wrong request: ST EUSTATIUS   , NT
# wrong request: EUGENE ISLAND  , GM
# wrong request: Stockstaff am Main, GE
# wrong request: SLOVAK REPUBLIC, LO
# wrong request: Nairegi Enkera, KE
# wrong request: PORCUPINE LODGE, AK, USA
# wrong request: South Tim Bailier Platform, GM, USA
# wrong request: Gelsdorf, GE
# wrong request: Hodkovice, EZ
# wrong request: Muzino Village, RS
# wrong request: Zhuhai Sanzao Airport, CH
# wrong request: WEST CAICOS ISL, TK
# wrong request: English Channel, UK
# wrong request: Karelia, RS
# wrong request: WALKERS CAY    , BF
# wrong request: Heathrow IAP, UK
# wrong request: HI. NAT'L PARK , HI, USA
# wrong request: Darwin Aerodrome, AS
# wrong request: San Felipe, CI
# wrong request: Albrook, PM
# wrong request: Jena-Isserstedt, GE
# wrong request: South Timbalier 127, GM, USA
# wrong request: TAMBON THA CHAL, IN
# wrong request: Ramstein, GE
# wrong request: Dhoyntji, AS
# wrong request: Kempton, Germany, GE
# wrong request: CATAMARA, EC
# wrong request: RIO SIDRA      , PM
# wrong request: Channel Islands, AO, UK
# wrong request: Shakar Darah District, AF
# wrong request: CONGOTOWN      , CF
# wrong request: MANGROVE KEY   , CF
# wrong request: Boquete, PM
# wrong request: Monastir, TS
# wrong request: Curico, CI
# wrong request: EAST CAMERON   , GM
# wrong request: MUSTANG ISLAND , GM
# wrong request: GULF OF MEXICO , GM
# wrong request: La Campa, HO
# wrong request: LAS MESITAS    , HO
# wrong request: SHIP SHOAL BLK , GM
# wrong request: POLK INLET     , AK, USA
# wrong request: Marmara Sea, TU
# wrong request: Sulzberg, GE
# wrong request: CAT CAY        , BF
# wrong request: 100MI S.KNG SLM, AK, USA
# wrong request: ROCK SOUND     , BF
# wrong request: Melbach, GE
# wrong request: CATACAMAS, HO
# wrong request: Pianello/Carena, SZ
# wrong request: Solroed Strand, DA
# wrong request: Oberbarnim, GE
# wrong request: HINCHE, HA
# wrong request: Heist, GE
# wrong request: Daimontaro, EC
# wrong request: Mostóles, SP
# wrong request: FRESH CREEK    , CF
# wrong request: Mediterranean, SP
# wrong request: W Cameron 168, GM, USA
# wrong request: EUGENE ISLAND  , GM
# wrong request: CESIS          , LG

# %%
need_location.iloc[0:2000]
# Out:
#                    ev_city ev_country ev_state   latitude longitude
# 46         NIGHTMUTE              USA       AK  60.479444  -164.724
# 50         UTICA                  USA       NY  43.100903  -75.2327
# 56                 Toronto         CA      NaN  43.653226  -79.3832
# 92                  Sydney         AS      NaN -33.972048   151.144
# 116        GRAND JUNCTION         USA       CO  39.063871  -108.551
# 120        JUNEAU                 USA       AK  58.301944   -134.42
# 129        YUBA CITY              USA       CA  39.140448  -121.617
# 149                 Sidney        USA       MT  47.716684  -104.156
# 153      Lake in the Woods         CA       ON  49.647675  -94.5553
# 163        KEMMERER               USA       WY  41.792447  -110.538
# 187                  Anaco         VE      NaN   9.429230  -64.4674
# 257        UMIAT                  USA       AK  69.367233  -152.143
# 296            LA FORTUNA          PA      NaN   8.744181  -82.2498
# 298                Bologna         IT      NaN  44.494887   11.3426
# 325                Madinah         SA      NaN  24.524654   39.5692
# 402        ATLANTA                USA       GA  33.748995   -84.388
# 435        HINCHINBROOK           USA       AK  60.415962  -146.585
# 442        SOUTH BEND             USA       IN  41.676355   -86.252
# 472             Arnos Vale         VC      NaN  13.143778  -61.2088
# 485              Portreath         UK      NaN  50.260642  -5.28866
# 489        AMERICAN RIVER         USA       AK  57.639234  -152.519
# 498                Raleigh        USA       NC  35.779590  -78.6382
# 499        BENSON                 USA       AZ  31.967861  -110.295
# 524        VIEKODA BAY            USA       AK  57.924722  -153.258
# 530        JAGO RIVER             USA       AK  69.083684  -143.574
# ...                    ...        ...      ...        ...       ...
# 34633      DENVER                 USA       CO  39.739236   -104.99
# 34637      Puerta del Segu         SP      NaN -20.767636  -49.3985
# 34655      FRIDAY HARBOR          USA       WA  48.534266  -123.017
# 34688           Santa Rosa         EC      NaN  -3.459389  -79.9668
# 34707      MCGRATH                USA       AK  62.953204  -155.596
# 34731      KANSAS CITY            USA       MO  39.099727  -94.5786
# 34733      EUGENE ISLAND          NaN       GM        NaN       NaN
# 34765             Brussels         BE      NaN  50.850340   4.35171
# 34774      DUTCH HARBOR           USA       AK  53.889800  -166.542
# 34781               Denver        USA       CO  39.739236   -104.99
# 34810      PRUDHOE BAY            USA       AK  70.255645  -148.338
# 34818      DUFUR                  USA       OR  45.453175  -121.131
# 34841  Ballarat, Australia         AS      NaN -37.563649   143.867
# 34861      WEST LAFAYETTE         USA       IN  40.425869  -86.9081
# 34898      PUERTO PLATA            DR      NaN  19.780769  -70.6871
# 34909          Mexico City         MX      NaN  19.432608  -99.1332
# 34933      CESIS                   LG      NaN        NaN       NaN
# 34940      MEMPHIS                USA       TN  35.149534   -90.049
# 34947         Col de Menee         FR      NaN  44.746809   5.57463
# 35010      CHICAGO                USA       IL  41.878114  -87.6298
# 35025      MUSKEGON               USA       MI  43.234181  -86.2484
# 35031                Tokyo         JA      NaN  35.787320   139.658
# 35096               TAIPEI         TW      NaN  25.032969   121.565
# 35119      TALKEETNA              USA       AK  62.320905  -150.107
# 35153       RANCHO CORDOVA        USA       CA  38.589072  -121.303
#
# [2000 rows x 5 columns]

# %%
need_location.iloc[2000:]
# Out:
#                 ev_city ev_country ev_state  latitude longitude
# 35161             Miami        USA       FL       NaN       NaN
# 35187   CEDAR RAPIDS           USA       IA       NaN       NaN
# 35202   BURBANK                USA       CA       NaN       NaN
# 35212   BEDFORD PARK           USA       IL       NaN       NaN
# 35238   GARDNER                USA       KS       NaN       NaN
# 35240   FORT MYERS             USA       FL       NaN       NaN
# 35244   BETHEL                 USA       AK       NaN       NaN
# 35250     Naha, Okinawa         JA      NaN       NaN       NaN
# 35272          Godensee         AU      NaN       NaN       NaN
# 35275   MANILA                  RP      NaN       NaN       NaN
# 35283   CHARLESTON             USA       SC       NaN       NaN
# 35309      Candido Mota         BR      NaN       NaN       NaN
# 35310   QUITO                   EC      NaN       NaN       NaN
# 35365              BUGA         CO      NaN       NaN       NaN
# 35390   SAINT MARYS            USA       AK       NaN       NaN
# 35391   MONTEREY               USA       CA       NaN       NaN
# 35408   DAVENPORT              USA       IA       NaN       NaN
# 35481   JAMAICA                USA       NY       NaN       NaN
# 35487   Ciudad Victoria         MX      NaN       NaN       NaN
# 35517   JACKSONVILLE           USA       FL       NaN       NaN
# 35527   BIRMINGHAM             USA       AL       NaN       NaN
# 35538   QUINCY                 USA       CA       NaN       NaN
# 35544        El Marques         MX      NaN       NaN       NaN
# 35554       Ciudad Real         SP      NaN       NaN       NaN
# 35567   BULLHEAD CITY          USA       AZ       NaN       NaN
# ...                 ...        ...      ...       ...       ...
# 76475         Cochenour         CA      NaN       NaN       NaN
# 76493   BASEPOHL                GE      NaN       NaN       NaN
# 76498   OFFSHORE OIL           NaN       GM       NaN       NaN
# 76501   BERNARD                USA       IA       NaN       NaN
# 76503   NOME                   USA       AK       NaN       NaN
# 76505           BOLZANO         IT      NaN       NaN       NaN
# 76509       CELLE-ARLOH         GE      NaN       NaN       NaN
# 76540   TAMPA                  USA       FL       NaN       NaN
# 76576        Blackbushe         UK      NaN       NaN       NaN
# 76587   DARDANELLE             USA       CA       NaN       NaN
# 76593   DALHART                USA       TX       NaN       NaN
# 76596   HEBER CITY             USA       UT       NaN       NaN
# 76614   ST. IGNACE             USA       MI       NaN       NaN
# 76688   MIAMI                  USA       FL       NaN       NaN
# 76701   TULSA                  USA       OK       NaN       NaN
# 76712   MWANZA AIRPORT          TZ      NaN       NaN       NaN
# 76741      Barcelonette         FR      NaN       NaN       NaN
# 76750   LOS ANGELES            USA       CA       NaN       NaN
# 76776   GULF OF MEXICO         NaN       GM       NaN       NaN
# 76795  Mareeba Aerdrome         AS      NaN       NaN       NaN
# 76812           Banbury         UK      NaN       NaN       NaN
# 76836   VERMILLION 255B        NaN       GM       NaN       NaN
# 76846            Kigali         RW      NaN       NaN       NaN
# 76850   JUNEAU                 USA       AK       NaN       NaN
# 76878           Cozumel         MX      NaN       NaN       NaN
#
# [2307 rows x 5 columns]

# %%
# Part 2: 2000:end
for ii in range(2000, len(need_location)):
    location = Session.get_lat_lon_from_city_country(cities[ii], countries[ii], states[ii])
    if location != []:
        lat = location[0]
        lon = location[1]
        need_location.set_value(index[ii], 'latitude', lat)
        need_location.set_value(index[ii], 'longitude', lon)
        

need_location.iloc[2000:].to_csv('./data/have_location_part2.csv')
# Out:
# wrong request: Kansai, JA
# wrong request: Sucre, FN, BL
# wrong request: Evora, FN, PO
# wrong request: Googlong, NSW, AS
# wrong request: Bosnia, BK
# wrong request: TREASURE CAY   , BF
# wrong request: W. CAMERON 617 , GM
# wrong request: VERMILION 250  , GM
# wrong request: TREASURE CAY   , BF
# wrong request: DUNCAN TOWN    , BF
# wrong request: EUCEMBUNE      , AS
# wrong request: SHIP SHOAL 225 , GM
# wrong request: TUCUTI , PM
# wrong request: Makung Island, TW
# wrong request: Rumbek, SU
# wrong request: EC 270, GM, USA
# wrong request: GULF-OF-MEXICO , GM
# wrong request: GULF OF MEXICO , GM
# wrong request: GULF OF MEXICO , GM
# wrong request: STELLA MARIS   , BF
# wrong request: Goma, CF
# wrong request: SOTO CANO, HO
# wrong request: PERDE BAY      , AK, USA
# wrong request: RANCHO SANTA YN, MX
# wrong request: Bourke , Australia, AS
# wrong request: MIXCOLAJA      , GT
# ---------------------------------------------------------------------------
# _RetriableRequest                         Traceback (most recent call last)
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     222             else:
# --> 223                 result = self._get_body(resp)
#     224             self.sent_times.append(time.time())
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get_body(self, resp)
#     241         if api_status == "OVER_QUERY_LIMIT":
# --> 242             raise googlemaps.exceptions._RetriableRequest()
#     243
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     222             else:
# --> 223                 result = self._get_body(resp)
#     224             self.sent_times.append(time.time())
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get_body(self, resp)
#     241         if api_status == "OVER_QUERY_LIMIT":
# --> 242             raise googlemaps.exceptions._RetriableRequest()
#     243
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     222             else:
# --> 223                 result = self._get_body(resp)
#     224             self.sent_times.append(time.time())
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get_body(self, resp)
#     241         if api_status == "OVER_QUERY_LIMIT":
# --> 242             raise googlemaps.exceptions._RetriableRequest()
#     243
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     222             else:
# --> 223                 result = self._get_body(resp)
#     224             self.sent_times.append(time.time())
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get_body(self, resp)
#     241         if api_status == "OVER_QUERY_LIMIT":
# --> 242             raise googlemaps.exceptions._RetriableRequest()
#     243
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     222             else:
# --> 223                 result = self._get_body(resp)
#     224             self.sent_times.append(time.time())
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get_body(self, resp)
#     241         if api_status == "OVER_QUERY_LIMIT":
# --> 242             raise googlemaps.exceptions._RetriableRequest()
#     243
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     222             else:
# --> 223                 result = self._get_body(resp)
#     224             self.sent_times.append(time.time())
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get_body(self, resp)
#     241         if api_status == "OVER_QUERY_LIMIT":
# --> 242             raise googlemaps.exceptions._RetriableRequest()
#     243
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     222             else:
# --> 223                 result = self._get_body(resp)
#     224             self.sent_times.append(time.time())
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get_body(self, resp)
#     241         if api_status == "OVER_QUERY_LIMIT":
# --> 242             raise googlemaps.exceptions._RetriableRequest()
#     243
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     222             else:
# --> 223                 result = self._get_body(resp)
#     224             self.sent_times.append(time.time())
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get_body(self, resp)
#     241         if api_status == "OVER_QUERY_LIMIT":
# --> 242             raise googlemaps.exceptions._RetriableRequest()
#     243
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     222             else:
# --> 223                 result = self._get_body(resp)
#     224             self.sent_times.append(time.time())
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get_body(self, resp)
#     241         if api_status == "OVER_QUERY_LIMIT":
# --> 242             raise googlemaps.exceptions._RetriableRequest()
#     243
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     222             else:
# --> 223                 result = self._get_body(resp)
#     224             self.sent_times.append(time.time())
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get_body(self, resp)
#     241         if api_status == "OVER_QUERY_LIMIT":
# --> 242             raise googlemaps.exceptions._RetriableRequest()
#     243
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     222             else:
# --> 223                 result = self._get_body(resp)
#     224             self.sent_times.append(time.time())
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get_body(self, resp)
#     241         if api_status == "OVER_QUERY_LIMIT":
# --> 242             raise googlemaps.exceptions._RetriableRequest()
#     243
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# Timeout                                   Traceback (most recent call last)
# <ipython-input-12-1d99b376712c> in <module>()
#       1 # Part 2: 2000:end
#       2 for ii in range(2000, len(need_location)):
# ----> 3     location = Session.get_lat_lon_from_city_country(cities[ii], countries[ii], states[ii])
#       4     if location != []:
#       5         lat = location[0]
#
# /home/asaez/aero/PyData_Madrid_2016/remove_before_flight/utils/geoloc.py in get_lat_lon_from_city_country(self, city, country, state)
#      51             print(params)
#      52
# ---> 53         geocode_result = self.gmaps.geocode(address)
#      54
#      55         try:
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/geocoding.py in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ---> 68     return client._get("/maps/api/geocode/json", params)["results"]
#      69
#      70
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     227             # Retry request.
#     228             return self._get(url, params, first_request_time, retry_counter + 1,
# --> 229                              base_url, accepts_clientid, extract_body)
#     230
#     231     def _get_body(self, resp):
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     227             # Retry request.
#     228             return self._get(url, params, first_request_time, retry_counter + 1,
# --> 229                              base_url, accepts_clientid, extract_body)
#     230
#     231     def _get_body(self, resp):
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     227             # Retry request.
#     228             return self._get(url, params, first_request_time, retry_counter + 1,
# --> 229                              base_url, accepts_clientid, extract_body)
#     230
#     231     def _get_body(self, resp):
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     227             # Retry request.
#     228             return self._get(url, params, first_request_time, retry_counter + 1,
# --> 229                              base_url, accepts_clientid, extract_body)
#     230
#     231     def _get_body(self, resp):
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     227             # Retry request.
#     228             return self._get(url, params, first_request_time, retry_counter + 1,
# --> 229                              base_url, accepts_clientid, extract_body)
#     230
#     231     def _get_body(self, resp):
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     227             # Retry request.
#     228             return self._get(url, params, first_request_time, retry_counter + 1,
# --> 229                              base_url, accepts_clientid, extract_body)
#     230
#     231     def _get_body(self, resp):
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     227             # Retry request.
#     228             return self._get(url, params, first_request_time, retry_counter + 1,
# --> 229                              base_url, accepts_clientid, extract_body)
#     230
#     231     def _get_body(self, resp):
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     227             # Retry request.
#     228             return self._get(url, params, first_request_time, retry_counter + 1,
# --> 229                              base_url, accepts_clientid, extract_body)
#     230
#     231     def _get_body(self, resp):
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     227             # Retry request.
#     228             return self._get(url, params, first_request_time, retry_counter + 1,
# --> 229                              base_url, accepts_clientid, extract_body)
#     230
#     231     def _get_body(self, resp):
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     227             # Retry request.
#     228             return self._get(url, params, first_request_time, retry_counter + 1,
# --> 229                              base_url, accepts_clientid, extract_body)
#     230
#     231     def _get_body(self, resp):
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     227             # Retry request.
#     228             return self._get(url, params, first_request_time, retry_counter + 1,
# --> 229                              base_url, accepts_clientid, extract_body)
#     230
#     231     def _get_body(self, resp):
#
# /miniconda/envs/pydata-safety/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     182         elapsed = datetime.now() - first_request_time
#     183         if elapsed > self.retry_timeout:
# --> 184             raise googlemaps.exceptions.Timeout()
#     185
#     186         if retry_counter > 0:
#
# Timeout:

# %%
need_location.iloc[2000:]
# Out:
#      ev_city ev_country ev_state   latitude longitude
# 2000     NaN        NaN      NaN  25.761680  -80.1918
# 2001     NaN        NaN      NaN  41.977880  -91.6656
# 2002     NaN        NaN      NaN  34.180839  -118.309
# 2003     NaN        NaN      NaN  41.764172  -87.7813
# 2004     NaN        NaN      NaN  38.810841  -94.9272
# 2005     NaN        NaN      NaN  26.640628  -81.8723
# 2006     NaN        NaN      NaN  60.792222  -161.756
# 2007     NaN        NaN      NaN  26.195134    127.67
# 2008     NaN        NaN      NaN  48.143000   11.4249
# 2009     NaN        NaN      NaN  14.599512   120.984
# 2010     NaN        NaN      NaN  32.776475  -79.9311
# 2011     NaN        NaN      NaN -22.746667   -50.388
# 2012     NaN        NaN      NaN  -0.180653  -78.4678
# 2013     NaN        NaN      NaN   3.900508  -76.3022
# 2014     NaN        NaN      NaN  62.053056  -163.166
# 2015     NaN        NaN      NaN  36.600238  -121.895
# 2016     NaN        NaN      NaN  41.523644  -90.5776
# 2017     NaN        NaN      NaN  40.702677   -73.789
# 2018     NaN        NaN      NaN  23.736916  -99.1411
# 2019     NaN        NaN      NaN  30.332184  -81.6557
# 2020     NaN        NaN      NaN  33.520661  -86.8025
# 2021     NaN        NaN      NaN  39.936836  -120.947
# 2022     NaN        NaN      NaN  20.583596  -100.373
# 2023     NaN        NaN      NaN -23.632536  -46.7391
# 2024     NaN        NaN      NaN  35.135939  -114.529
# ...      ...        ...      ...        ...       ...
# 4276     NaN        NaN      NaN  40.735657  -74.1724
# 4277     NaN        NaN      NaN  64.837778  -147.716
# 4278     NaN        NaN      NaN  44.552011  -69.6317
# 4279     NaN        NaN      NaN  60.218889  -162.024
# 4281     NaN        NaN      NaN  14.634915  -90.5069
# 4282     NaN        NaN      NaN  51.071425  -93.8072
# 4285     NaN        NaN      NaN  42.312230  -90.8318
# 4286     NaN        NaN      NaN  64.501111  -165.406
# 4287     NaN        NaN      NaN  46.498295   11.3548
# 4288     NaN        NaN      NaN  52.617596   10.0629
# 4289     NaN        NaN      NaN  27.950575  -82.4572
# 4290     NaN        NaN      NaN  51.877178  0.178349
# 4291     NaN        NaN      NaN  38.341023  -119.834
# 4292     NaN        NaN      NaN  36.059477  -102.513
# 4293     NaN        NaN      NaN  40.507009  -111.413
# 4294     NaN        NaN      NaN  45.875568  -84.7323
# 4295     NaN        NaN      NaN  25.761680  -80.1918
# 4298     NaN        NaN      NaN  44.386300   6.65046
# 4299     NaN        NaN      NaN  34.052234  -118.244
# 4301     NaN        NaN      NaN -16.991164   145.422
# 4302     NaN        NaN      NaN  52.062901  -1.33977
# 4303     NaN        NaN      NaN  42.779442  -96.9292
# 4304     NaN        NaN      NaN  -1.970579   30.1044
# 4305     NaN        NaN      NaN  58.301944   -134.42
# 4306     NaN        NaN      NaN  20.422984  -86.9223
#
# [2062 rows x 5 columns]

# %%
# Notebook style
from IPython.core.display import HTML
css_file = './static/style.css'
HTML(open(css_file, "r").read())
# Out:
# <link href='http://fonts.googleapis.com/css?family=Source+Sans+Pro|Josefin+Sans:400,700,400italic|Ubuntu+Condensed' rel='stylesheet' type='text/css'>
#
#
# <style>
#
# #notebook_panel { /* main background */
#     background: #f7f7f7;
# }
#
# div.cell { /* set cell width */
#     width: 900px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 950px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.7em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     font-family: 'Source Sans Pro', sans-serif;
#     background-color: rgb(256,256,256);
#     font-size: 110%;
#     border-radius: 0px;
#     padding: 0.5em;
#     margin-left:1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Josefin Sans', serif;
#     line-height: 145%;
#     font-size: 125%;
#     font-weight: 500;
#     width:750px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1, .text_cell_render h2, .text_cell_render h3,
# .text_cell_render h4, .text_cell_render h5 {
#     font-family: 'Ubuntu Condensed', sans-serif;
# }
#
# .text_cell_render h1 {    /*Use this for Title*/
#     font-weight: 500;
#     font-size: 38pt;
#     line-height: 100%;
#     color: #EE9141;
#     text-align: center;
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h2 {    /*Use this for Subtitle*/
#     margin-top:16px;
#     font-size: 32pt;
#     font-weight: 500;
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     text-align: center;
#     font-style: regular;
#     color: #459EBA;
# }
#
# .text_cell_render h3 {   /*Sections*/
#     font-size: 30pt;
#     font-weight: 300;
#     text-align: left;
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     font-style: regular;
#     color:  #252525;
# }
#
# .text_cell_render h4 {    /*Subsections*/
#     font-size: 28pt;
#     font-weight: 200;
#     text-align: left;
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     font-style: regular;
#     color:  #377e95;
# }
#
# .text_cell_render h5 {    /*Subsubsections*/
#     font-size: 20pt;
#     font-weight: 300;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
#     color:  #e77615;
# }
#
# .text_cell_render h6 {    /*Author*/
#     font-family: 'Ubuntu Condensed', sans-serif;
#     font-weight: 100;
#     font-size: 14pt;
#     line-height: 100%;
#     color: #252525;
#     text-align: right;
#     margin-bottom: 1px;
#     margin-top: 3px;
# }
#
# .CodeMirror{
#         font-family: 'Duru Sans', sans-serif;
#         font-size: 100%;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
