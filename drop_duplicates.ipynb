# %%
import pandas as pd

# %%
aircraft = pd.read_csv("./data/aircraft.csv",
                                    encoding = "ISO-8859-1", 
                                    sep=';')
events = pd.read_csv("./data/events.csv",
                                    sep='|')  
occurrences = pd.read_csv("./data/Occurrences1.csv",
                                    sep=';')
# Out:
# C:\Users\jesus\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (4,7,17,27,28,32,37,38,47,48,53,63,70,72,73,76,82) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\jesus\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.options.display.max_rows = 10
aircraft['ev_id'].value_counts()
# Out:
# 20001212X19172    3
# 20001214X45071    3
# 20100204X45658    3
# 20101022X34140    3
# 20070518X00587    2
#                  ..
# 20040726X01062    1
# 20001207X02891    1
# 20090706X10333    1
# 20060927X01405    1
# 20010110X00255    1
# Name: ev_id, dtype: int64

# %%
pd.options.display.max_columns = 93

aircraft[aircraft['ev_id'] == '20001212X19172']

# different rows for same ev_id :       'Aircraft_Key'  one for each aircraft involved in the accident
#                                       'damage'   
#                                       'phase_flt_spec'  there can be small differences in the phase of flight but they will
#                                                         belong to the same 'general phase'; example: 520, 500, 520
# Out:
#                 ev_id  Aircraft_Key regis_no      ntsb_no acft_missing  \
# 19288  20001212X19172             1   N712RD  CHI99FA266A            N
# 19289  20001212X19172             2    N14HP  CHI99FA266B            N
# 19290  20001212X19172             3   N179PT  CHI99FA266C            N
#
#       far_part flt_plan_filed flight_plan_activated damage acft_fire  \
# 19288      091           NONE                   NaN   DEST       GRD
# 19289      091           NONE                   NaN   SUBS      NONE
# 19290      091           NONE                   NaN   SUBS      NONE
#
#       acft_expl      acft_make acft_model acft_series acft_serial_no  \
# 19288      NONE  Chance Vought      F4U-4       F4U-4          97280
# 19289      NONE        Grumman      F8F-1       F8F-1          90446
# 19290      NONE  Chance Vought      F4U-5       F4U-5         122179
#
#        cert_max_gr_wt acft_category acft_reg_cls homebuilt  fc_seats  \
# ...

# %%
pd.options.display.max_columns = 71
pd.options.display.max_rows = 3
 
events['ev_id'].value_counts()
# Out:
# C:\Users\jesus\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 20081004X12033    1
#                  ..
# 20111013X34429    1
# Name: ev_id, dtype: int64

# %%
pd.options.display.max_rows = 10

occurrences['ev_id'].value_counts()
# Out:
# 20020917X02282    8
# 20001211X09798    8
# 20001214X37511    8
# 20001214X35691    7
# 20020917X04016    7
#                  ..
# 20001211X11501    1
# 20001207X03053    1
# 20001212X16623    1
# 20020917X03588    1
# 20001213X31466    1
# Name: ev_id, dtype: int64

# %%
pd.options.display.max_columns = 8
pd.options.display.max_columns = 10

occurrences[occurrences['ev_id'] == '20020917X02282']

# we can reach a conclusion: when we are looking for the 'Occurrence_Code' we do not have to use drop_duplicates here; however when
#                            we are looking for the Phase_of_Flight we do need to use drop_duplicates['Occurrence_Code'] in order 
#                            to avoid the repetition of the same 'Phase_of_Flight' when there must be one for each airplane
# Out:
#                  ev_id  Aircraft_Key  Occurrence_No  Occurrence_Code  \
# 109961  20020917X02282             1              1              270
# 109962  20020917X02282             1              2              250
# 109963  20020917X02282             1              3              430
# 109964  20020917X02282             1              4              230
# 109965  20020917X02282             2              1              270
# 109966  20020917X02282             2              2              250
# 109967  20020917X02282             2              3              430
# 109968  20020917X02282             2              4              230
#
#         Phase_of_Flight  Altitude   lchg_date lchg_userid
# 109961              531         0  17/09/2002         dbo
# 109962              553         0  17/09/2002         dbo
# 109963              553         0  17/09/2002         dbo
# 109964              553         0  17/09/2002         dbo
# ...
